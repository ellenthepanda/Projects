# %%
import pandas as pd
import matplotlib.pyplot as plt

#Importing the data
Cov = pd.read_csv("http://www.hep.ucl.ac.uk/undergrad/3459/data/module6/module6-data.txt", 
                  sep='  ',
                  names=["x_pos", "y_pos", "weight", "weight_info"])
df = pd.DataFrame(Cov) 
df = df.rename_axis("rock_id").reset_index()

# Create data
x1 = df["x_pos"]
y1 = df["y_pos"]
x2 = df["x_pos"].mean()
y2 = df["y_pos"].mean()

# Plot
plt.scatter(x1, y1)
plt.scatter(x2,y2)
plt.title('Scatter plot: location of rocks')
plt.xlabel('x-position')
plt.ylabel('y-position')
plt.show()
# Out:
# <ipython-input-21-d443fa68848e>:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   Cov = pd.read_csv("http://www.hep.ucl.ac.uk/undergrad/3459/data/module6/module6-data.txt",
